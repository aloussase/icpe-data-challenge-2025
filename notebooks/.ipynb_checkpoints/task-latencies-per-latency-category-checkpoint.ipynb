# %%
import polars as pl
import polars.selectors as cs
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_style('whitegrid')

# %%
tasks = pl.read_csv('../datasets/GlobusComputeDataset-v1-tasks.csv')

# %%
tasks = tasks.fill_nan(None).drop_nulls(subset=cs.numeric())

# %%
functions = pl.read_csv('../datasets/functions_collect.csv', separator=";", has_header=False, new_columns=['ID', 'cluster'])

# %%
tasks = (
    tasks
        .with_columns_seq(end_to_end=(pl.col("result_received") - pl.col("received")) / 1000000000)
        .with_columns_seq(
            pl
             .when(pl.col('end_to_end') < 30).then(pl.lit('LOW'))
             .when(pl.col('end_to_end') < 45).then(pl.lit('30'))
             .when(pl.col('end_to_end') < 80).then(pl.lit('45'))
             .otherwise(pl.lit('80'))
             .alias('latyp')
        )
)

# %%
tasks = tasks.select(
    pl.col('end_to_end'),
    pl.col('latyp'),
    pl.col('function_uuid')
).join(functions, left_on='function_uuid', right_on='ID')

# %%
tasks['cluster'].value_counts()
# Out:
# shape: (5, 2)
# ┌──────────────────────┬──────────┐
# │ cluster              ┆ count    │
# │ ---                  ┆ ---      │
# │ str                  ┆ u32      │
# ╞══════════════════════╪══════════╡
# │ Job Scheduling       ┆ 2193679  │
# │ ML                   ┆ 673042   │
# │ Scientific Computing ┆ 4044188  │
# │ Trivial              ┆ 41335151 │
# │ Unclustered          ┆ 7607     │
# └──────────────────────┴──────────┘

# %%
non_trivial_tasks = tasks.filter(
    pl.col('cluster') != 'Trivial',
    pl.col('cluster') != 'Job Scheduling',
    pl.col('cluster') != 'Unclustered',
)

# %%
compute_pct = lambda series, min, max: (series.filter((series >= min) & (series < max)).len() / series.len()) * 100

# %%
def compute_latencies(df):
    return pl.DataFrame({
        'pct': [
            compute_pct(df['end_to_end'], 0, 30),
            compute_pct(df['end_to_end'], 30, 45),
            compute_pct(df['end_to_end'], 45, 80),
            compute_pct(df['end_to_end'], 80, float('inf'))
        ], 
        'latcat': ['< 30s', '>= 30s', '>= 45s', '>= 80s']
    })

# %%
categories = compute_latencies(non_trivial_tasks)

plt.figure(figsize=(6, 6))

sns.barplot(categories, y='pct', x='latcat', hue='latcat', alpha=.7)

for index, row in enumerate(categories.iter_rows(named=True)):
    pct = row['pct']
    plt.text(index, pct+1, f'{pct:.0f}%', color='black', va="center")

plt.title('Percentage of Tasks in Different Latency Categories\n(Ignoring trivial and job scheduling tasks)')
plt.xlabel('Latency Category')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
by_cluster = tasks.group_by('cluster')

# %%
by_cluster = {cluster[0]: compute_latencies(df) for cluster, df in by_cluster}

# %%
by_cluster.keys()
# Out:
# dict_keys(['Trivial', 'Scientific Computing', 'Job Scheduling', 'Unclustered', 'ML'])

# %%
def plot_category(categories, category, ax):
    sns.barplot(categories[category], y='pct', x='latcat', hue='latcat', alpha=.7, ax=ax)
    ax.set_title(category)
    ax.set_ylabel('')
    
    for index, row in enumerate(categories[category].iter_rows(named=True)):
        pct = row['pct']
        ax.text(index, pct+1, f'{pct:.0f}%', color='black', va="center")


fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, figsize=(10, 10))

plot_category(by_cluster, 'ML', axes[0, 0])
plot_category(by_cluster, 'Scientific Computing', axes[0, 1])
plot_category(by_cluster, 'Job Scheduling', axes[1, 0])
plot_category(by_cluster, 'Unclustered', axes[1, 1])

fig.suptitle('Task latencies in different function clusters')
# Out:
# Text(0.5, 0.98, 'Task latencies in different function clusters')
